# %% [markdown]
# # Unidad 1. Regresión lineal simple y correlación

# %% [markdown]
# ## Medidas de dispersión
# Suma de los cuadrados de las desviaciones de los valores de $X$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (X_i - \bar{X})^2 $$
# Suma de los productos de las desviaciones de los valores de $X$ y $Y$ con respecto a sus medias:
# $$S_{xy} = \sum_{i=1}^{n} (X_i - \bar{X})(Y_i - \bar{Y})$$
# Suma de los cuadrados de las desviaciones de los valores de $Y$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (Y_i - \bar{Y})^2 $$

# %% [markdown]
# ## Coeficiente de correlación y de determinación
# Coeficiente de correlación de Pearson:
# $$ r = \frac{S_{xy}}{\sqrt{S_{xx} \cdot S_{yy}}} $$
# Coeficiente de determinación:
# $$ r^2 $$

# %% [markdown]
# ## Recta de regresión ajustada
# La regresión lineal ajustada se representa mediante estadísticos:
# $$ \hat{Y} = b_0 + b_1 X $$
# donde $\hat{Y}$ representa el valor de $Y$ obtenido mediante la recta de regresión ajustada (no la verdadera $Y$). Los estadísticos $b_0$ y $b_1$ se calculan de la siguiente manera:
#
# $$b_1 = \frac{S_{xy}}{S_{xx}}$$
#
# $$ b_0 = \bar{Y} - b_1 \bar{X} $$

# %% [markdown]
# ## Cálculo de residuales
# Residuales:
# $$e_i = Y_i - \hat{Y}_i$$

# %% [markdown]
# ## Sumas de cuadrados SS (Sum of Squares)
# Suma de los Cuadrados de los Errores:
# $$ SSE = \sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2 = \sum_{i=1}^n e_i^2$$
# Suma total de cuadrados:
# $$SST = \sum_{i=1}^{n} (Y_i - \bar{Y})^2$$
# Suma de cuadrados de regresión:
# $$SSR = \sum_{i=1}^{n} (\hat{Y_i} - \bar{Y})^2$$
# - SST: Mide la variabilidad total de los datos observados.
# - SSR: Mide la variabilidad de los datos que el modelo de regresión explica.
# - SSE: Mide la variabilidad no explicada por el modelo (es decir, los residuos).

# %% [markdown]
# ## Intervalo de confianza
# Estadístico de prueba _t_:
# $$t = \frac{b_1}{SE(b_1)}$$
# Error estándar de $b_1$:
# $$SE(b_1) = \frac{\sqrt{SSE / (n-2)}}   {\sqrt{S_{xx}} }$$
# o
# $$SE(b_1) = \frac{\sqrt{\sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2  / (n-2)}}   {\sqrt{S_{xx}} }$$
#
# Intervalo de confianza para $b_1$:
# $$b_1 - t_{\alpha/2} \cdot SE(b_1) \lt \beta_1 \lt b_1 + t_{\alpha/2} \cdot SE(b_1)$$
# donde $n$ representa la cantidad de pares de datos.

# %% [markdown]
# ## Comprobación de supuestos
# Comprobar suposiciones:
# - Test de shapiro a los residuales $e_i$: Para comprobar si la distribución es normal sobre la recta.
# - Grafico $X$ vs $Y$: Para observar si los datos soportan la suposición de linealidad.
# - Gráfico de residuales: Para observar si los datos soportan la suposición de linealidad, complementario al coeficiente de correlación
# - Test de Breusch-Pagan: Para detectar heteroscedasticidad en regresion lineal

# %% [markdown]
# Test de Shapiro:<br>
# `from scipy.stats import shapiro`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_sh = shapiro(data)`<br>
# - $H_0$: Los datos siguen una distribución normal
# - $H_1$: Los datos no siguen una distribución normal

# %% [markdown]
# Test de Breusch-Pagan:<br>
# `from statsmodels.stats.api import het_breuschpagan`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_bp, _, _ = het_breuschpagan(residuales, X)`
# - $H_0$: Hay homoscedasticidad
# - $H_1$: Hay heteroscedasticidad

# %% [markdown]
# ## ANOVA en regresión lineal
#
# | Fuente de variación | Suma de cuadrados (SS) | Grados de libertad (df) | Promedio de los cuadrados (MS) | Estadístico F |
# |---------------------|------------------------|--------------------------|--------------------------------|---------------|
# | Regresión  | $ SSR$ | $p$ | $MSR = \frac{SSR}{p}$ | $F = \frac{MSR}{MSE}$|
# | Error | $SSE$| $n - p - 1 $| $MSE = \frac{SSE}{n - p - 1} $|     |
# | Total | $SST $| $n - 1$|             |        |
#
# donde $p$ es el número de parámetros para la recta de regresión ajustada (en la regresión simple $p=1$). Las hipótesis son:
# $$H_0: \beta_1 = 0$$
# $$H_1: \beta_1 \ne 0 $$

# %% [markdown]
# ## Problemario de la Unidad 1

# %% [markdown]
# ### Problema 1
# Un profesor intenta mostrar a sus estudiantes la importancia de los exámenes cortos, aun cuando el 90% de la calificación final esté determinada por los exámenes parciales. Él cree que cuanto más altas sean las calificaciones de los exámenes cortos, más alta será la calificación final. Seleccionó una muestra aleatoria de 15 estudiantes de su clase con los siguientes datos:
#
# | Promedio de exámenes cortos | Promedio final |
# |--------------|--------------|
# | 59 | 64 |
# | 92 | 84 |
# | 72 | 77 |
# | 90 | 80 |
# | 95 | 77 |
# | 87 | 81 |
# | 89 | 80 |
# | 77 | 84 |
# | 76 | 80 |
# | 65 | 69 |
# | 97 | 83 |
# | 42 | 40 |
# | 94 | 78 |
# | 62 | 65 |
# | 91 | 90 |
#
#
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
    "promedio_de_examenes_cortos":[59,92,72,90,95,87,89,77,76,65,97,42,94,62,91],
    "promedio_final":[64,84,77,80,77,81,80,84,80,69,83,40,78,65,90]
})
df
# Out:
#     promedio_de_examenes_cortos  promedio_final
# 0                            59              64
# 1                            92              84
# 2                            72              77
# 3                            90              80
# 4                            95              77
# 5                            87              81
# 6                            89              80
# 7                            77              84
# 8                            76              80
# 9                            65              69
# 10                           97              83
# 11                           42              40
# 12                           94              78
# 13                           62              65
# 14                           91              90

# %%
#1 Establesca una variable dependiente ( Y ) y una variable independiente ( X )
y=df["promedio_final"]
x=df["promedio_de_examenes_cortos"]

# %%
#2 Realice un diagrama de dispersión para estos datos
import pandas as pd
df=pd.DataFrame({
    "promedio_de_examenes_cortos":[59,92,72,90,95,87,89,77,76,65,97,42,94,62,91],
    "promedio_final":[64,84,77,80,77,81,80,84,80,69,83,40,78,65,90]
})
import matplotlib.pyplot as plt
#configuracion general
plt.figure(
    figsize=(6,4), #tamaño (ancho,alto)
    dpi=100 #resoluciom
)
#Definir variables
x=df["promedio_de_examenes_cortos"]
y=df["promedio_final"]
#Grafico de dispersion
plt.scatter(
    x,y, #variables a graficar
    marker=".", #cambio de forma de los puntos
    color="#e330b2",
    edgecolor="#ab1281", #color del borde
    alpha=0.9, #transparencia
    s=60, #tamaño de cada punto
    label="promedio_final" #etiqueta
)
#Titulo
plt.title(
    "Grafica de dispersion",
    fontsize=12, #tamaño de fuente
    fontweight="bold" #bold:negritas
)

#Etiqueta eje x
plt.xlabel(
    "promedio_de_examenes_cortos",
    fontsize=10
)
#Etiqueta eje y
plt.ylabel(
    "promedio_final",
    fontsize=10
)

#Modificar tamaño de fuente (tamaño de Ticks) 10 es un buen tamaño
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Margenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False) #este codigo es para que no quede cuadrado :)

#Malla o cuadricula
plt.grid( #Este hace que se cuadricule la grafica
    visible=True, #True es que si la quieres y cuando se pone False es que no la quieres o no se va a poner (T o F se ponen en mayusculas)
    linestyle="--",
    linewidth=0.7, #ancho de la linea
    alpha=0.5, #transparencia
    color="#000000",
    )

#Leyenda (Lo que quiere decir los puntos o estrellas)
plt.legend(
    fontsize=10,
    loc="best",
    frameon=False, #si le ponemos False la cajita va a desaparecer, si le ponemos True va a aparecer
    bbox_to_anchor=(0.5,-0.15)
)

#Guardar imagen (entrar en la carpeta, darle en los 3 puntos y se guarda automaticamente)
plt.savefig(
    "dispersión",
    bbox_inches="tight"
)

# %%
#3 ¿Los datos soportan la suposición de linealidad?
#Sí, los datos sí apoyan que la relación sea lineal. En la gráfica de puntos se ve que cuando sube el promedio de los exámenes cortos, también sube el promedio final. Los puntos casi forman una línea hacia arriba, así que se puede decir que hay una relación positiva entre las dos cosas.

# %%
#4 Calcule el coeficiente de correlación e interprete el resultado.
#r=1 obtenemos una relación muy fuerte (perfecta hacia arriba)
#r=-1 obtenemos una relación muy fuerte pero al contrario (va hacia abajo)
#r=0 no hay correlación (obtenemos una relación nula)
from scipy.stats import pearsonr
r, valor_p=pearsonr (x,y)             #prueba de hipotesis
print(f"coeficiente de correlacion (r):{r:0.4f}")                                      #Ho:p=o no hay correción
print (f"{valor_p:0.4f}")                                                               #Hi:p=/o si hay correción
                                                                                       #corralación:el cambio de una variable esta vinculado con el cambio en otra variable
# Out:
# coeficiente de correlacion (r):0.8646
# 0.0000

# %%
#Interpretación: Hay una relación fuerte entre el promedio de los exámenes cortos y el promedio final. Como el valor p es menor que 0.05, se rechaza la hipótesis nula (H0), lo que significa que la relación sí es significativa.

# %%
# 5 Calcule el coeficiente de determinación e interprete el resultado.
#1 (*) es multimplicacion
#2 (**)en elevar la potencia
print(f"coeficiente de determinación: {r**2:0.4f}")
# Out:
# coeficiente de determinación: 0.7475

# %%
# Interpretación: El 74.75% de los cambios que hay en el promedio final se pueden explicar por el promedio de los exámenes cortos. El otro 25.25% depende de otras cosas que no se tomaron en cuenta en el modelo.

# %%
#6 Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)
modelo.params                                           #promedio final=0.6434(promedio_de_examenes_cortos)+24.54
# Out:
# const                          24.526822
# promedio_de_examenes_cortos     0.643180
# dtype: float64

# %%
import pandas as pd
df=pd.DataFrame({
    "promedio_de_examenes_cortos":[59,92,72,90,95,87,89,77,76,65,97,42,94,62,91],
    "promedio_final":[64,84,77,80,77,81,80,84,80,69,83,40,78,65,90]
})
import matplotlib.pyplot as plt
#configuracion general
plt.figure(
    figsize=(6,4), #tamaño (ancho,alto)
    dpi=100 #resoluciom
)
plt.scatter(
    x,y, #variables a graficar
    marker=".", #cambio de forma de los puntos
    color="#e330b2",
    edgecolor="#ab1281", #color del borde
    alpha=0.9, #transparencia
    s=60, #tamaño de cada punto
    label="promedio_final" #etiqueta
)
plt.plot(
    x,y_calculada,
)
#Titulo
plt.title(
    "Grafica de dispersion",
    fontsize=12, #tamaño de fuente
    fontweight="bold" #bold:negritas
)

#Etiqueta eje x
plt.xlabel(
    "promedio_de_examenes_cortos",
    fontsize=10
)
#Etiqueta eje y
plt.ylabel(
    "promedio_final",
    fontsize=10
)

#Modificar tamaño de fuente (tamaño de Ticks) 10 es un buen tamaño
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Margenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False) #este codigo es para que no quede cuadrado :)

#Malla o cuadricula
plt.grid( #Este hace que se cuadricule la grafica
    visible=True, #True es que si la quieres y cuando se pone False es que no la quieres o no se va a poner (T o F se ponen en mayusculas)
    linestyle="--",
    linewidth=0.7, #ancho de la linea
    alpha=0.5, #transparencia
    color="#000000",
    )

#Leyenda (Lo que quiere decir los puntos o estrellas)
plt.legend(
    fontsize=10,
    loc="best",
    frameon=False, #si le ponemos False la cajita va a desaparecer, si le ponemos True va a aparecer
    bbox_to_anchor=(0.5,-0.15)
)

#Guardar imagen (entrar en la carpeta, darle en los 3 puntos y se guarda automaticamente)
plt.savefig(
    "dispersión",
    bbox_inches="tight"
)

# %%
#7 Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )
modelo.conf_int(alpha=0.05)
# Out:
#                                     0          1
# const                        6.441997  42.611646
# promedio_de_examenes_cortos  0.419219   0.867141

# %%
#8 Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos? no hay
#residuales
residuales=modelo.resid
import matplotlib.pyplot as plt
#configuracion general
plt.figure(
    figsize=(6,4), #tamaño (ancho,alto)
    dpi=100 #resoluciom
)
#Grafico de dispersion
plt.scatter(
    x,residuales, #variables a graficar
    marker="H", #cambio de forma de los puntos
    color="#A60790", #YO CAMBIO
    edgecolor="#3D0235", #color del borde
    alpha=0.9, #transparencia
    s=60, #tamaño de cada punto
    label="promedio_final" #etiqueta
)
#Titulo
plt.title(
    "Grafica de dispersion",
    fontsize=12, #tamaño de fuente
    fontweight="bold" #bold:negritas
)
#Etiqueta eje x
plt.xlabel(
    "promedio_de_examenes_cortos",
    fontsize=10
)
#Etiqueta eje y
plt.ylabel(
    "promedio_final",
    fontsize=10
)
#Modificar tamaño de fuente (tamaño de Ticks) 10 es un buen tamaño
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Margenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False) #este codigo es para que no quede cuadrado :)

#Malla o cuadricula
plt.grid( #Este hace que se cuadricule la grafica
    visible=True, #True es que si la quieres y cuando se pone False es que no la quieres o no se va a poner (T o F se ponen en mayusculas)
    linestyle="--",
    linewidth=0.7, #ancho de la linea
    alpha=0.5, #transparencia
    color="#AB0392",
    )

#Leyenda (Lo que quiere decir los puntos o estrellas)
plt.legend(
    fontsize=10,
    loc="best",
    frameon=False, #si le ponemos False la cajita va a desaparecer, si le ponemos True va a aparecer
    bbox_to_anchor=(0.5,-0.15)
)
#Guardar imagen (entrar en la carpeta, darle en los 3 puntos y se guarda automaticamente)
plt.savefig(
    "dispersión",
    bbox_inches="tight"
)
plt.axhline(y=0, color="#AB0392", linestyle="--") #linea horizontal

# %%
# Respuesta: Esto quiere decir que sí se cumple la condición de que la relación sea lineal y que los datos tengan una variación parecida en todos los valores.

# %%
#9 Realice la prueba de Shapiro para los residuales y comente el resultado.
from scipy.stats import shapiro
estadistico, valor_p=shapiro(residuales)
print(f"valor_p:{valor_p:0.4f}")

#Valor_p:0.9018 es valor al nivel de significancia
#los residuales siguen una distribuccion normal
# Out:
# valor_p:0.9018

# %%
# Resultado: Como el valor p es mayor que 0.05, no se rechaza la hipótesis nula (H0). Esto significa que los residuales sí siguen una distribución normal.

# %%
#10 Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
from statsmodels.stats.api import het_breuschpagan
estadistico_1,valor_p_1,estadistico_2,valor_p_2=het_breuschpagan(residuales,x_constante)
print(f"valor_p:{valor_p_1:0.4f}")
#Ho:no hay heterocedasticidad (varianza uniforme) "ES ESTA"

#valor_p> niver de significancia
#0.2289>0.05
# Out:
# valor_p:0.2289

# %%
#Interpretación: Como el valor p es mayor que 0.05, no se rechaza la hipótesis nula (H0). Esto quiere decir que no se encontró evidencia de que exista heterocedasticidad, o sea, la variación se mantiene más o menos constante.

# %%
#11 Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?
#se casa en la tabla 6
#f(70)=24.53+0.6432(70)
modelo.predict([1,70])
# Out:
# array([69.54941193])

# %%
#11
modelo.predict([1,75])
# Out:
# array([72.76531124])

# %%
#11
modelo.predict([1,84])
# Out:
# array([78.55393001])

# %%
# Interpretación: De acuerdo con el modelo, si un estudiante saca 70 en sus exámenes cortos, su promedio final sería más o menos 69.55. Las demás predicciones funcionan igual, y muestran que cuando aumenta la calificación en los exámenes cortos, también aumenta el promedio final, siguiendo la misma tendencia.

# %%
#12 Realice una tabla ANOVA e interprete el resultado.
from statsmodels.formula.api import ols
#y ~ x
modelo_lineal=ols ("promedio_final ~ promedio_de_examenes_cortos", data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                                df       sum_sq      mean_sq          F  \
# promedio_de_examenes_cortos   1.0  1538.228959  1538.228959  38.492412
# Residual                     13.0   519.504375    39.961875        NaN
#
#                                PR(>F)
# promedio_de_examenes_cortos  0.000032
# Residual                          NaN

# %%
# Interpretación: El modelo de regresión sí es importante en términos estadísticos. Esto quiere decir que el promedio de los exámenes cortos sí influye de forma significativa en el promedio final.

# %% [markdown]
# ### Problema 2
# William Hawkins, vicepresidente de personal de la International Motors, trabaja en la relación entre el salario de un trabajador y el porcentaje de ausentismo. Hawkins dividió el intervalo de salarios de International en 12 grados o niveles (1 es el menor grado, 12 el más alto) y después muestreó aleatoriamente a un grupo de trabajadores. Determinó el grado de salario de cada trabajador y el número de días que ese empleado había faltado en los últimos 3 años.
#
# | Categoría de salario | 11 | 10 | 8  | 5  | 9  | 7  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 18 | 17 | 29 | 36 | 11 | 28 | 35 |
#
# | Categoría de salario | 11 | 8  | 7  | 2  | 9  | 8  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 14 | 20 | 32 | 39 | 16 | 31 | 40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
#1 Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
import pandas as pd
df=pd.DataFrame({
    "categoria_de_salario":[11,10,8,5,9,7,3,11,8,7,2,9,8,3],
    "ausencias":[18,17,29,36,11,28,35,14,20,32,39,16,31,40]
})
df
# Out:
#     categoria_de_salario  ausencias
# 0                     11         18
# 1                     10         17
# 2                      8         29
# 3                      5         36
# 4                      9         11
# 5                      7         28
# 6                      3         35
# 7                     11         14
# 8                      8         20
# 9                      7         32
# 10                     2         39
# 11                     9         16
# 12                     8         31
# 13                     3         40

# %%
#2 Realice un diagrama de dispersión para estos datos.
import pandas as pd
df=pd.DataFrame({
    "categoria_de_salario":[11,10,8,5,9,7,3,11,8,7,2,9,8,3],
    "ausencias":[18,17,29,36,11,28,35,14,20,32,39,16,31,40]
})
import matplotlib.pyplot as plt
#configuracion general
plt.figure(
    figsize=(6,4), #tamaño (ancho,alto)
    dpi=100 #resoluciom
)
#Definir variables
x=df["categoria_de_salario"]
y=df["ausencias"]
#Grafico de dispersion
plt.scatter(
    x,y, #variables a graficar
    marker="H", #cambio de forma de los puntos
    color="#e330b2",
    edgecolor="#ab1281", #color del borde
    alpha=0.9, #transparencia
    s=60, #tamaño de cada punto
    label="ausencias" #etiqueta
)
#Titulo
plt.title(
    "Grafica de dispersion",
    fontsize=12, #tamaño de fuente
    fontweight="bold" #bold:negritas
)

#Etiqueta eje x
plt.xlabel(
    "categoria_de_salario",
    fontsize=10
)
#Etiqueta eje y
plt.ylabel(
    "ausencias",
    fontsize=10
)

#Modificar tamaño de fuente (tamaño de Ticks) 10 es un buen tamaño
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Margenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False) #este codigo es para que no quede cuadrado :)

#Malla o cuadricula
plt.grid( #Este hace que se cuadricule la grafica
    visible=True, #True es que si la quieres y cuando se pone False es que no la quieres o no se va a poner (T o F se ponen en mayusculas)
    linestyle="--",
    linewidth=0.7, #ancho de la linea
    alpha=0.5, #transparencia
    color="#000000",
    )

#Leyenda (Lo que quiere decir los puntos o estrellas)
plt.legend(
    fontsize=10,
    loc="best",
    frameon=False, #si le ponemos False la cajita va a desaparecer, si le ponemos True va a aparecer
    bbox_to_anchor=(0.5,-0.15)
)

# %%
#3 ¿Los datos soportan la suposición de linealidad?
#Respuesta: En la gráfica se observa que los puntos van bajando. Eso significa que mientras más alta es la categoría de salario, menos ausencias hay. Por eso se puede decir que sí se cumple la suposición de linealidad.

# %%
#4 Calcule el coeficiente de correlación e interprete el resultado.
from scipy.stats import pearsonr
r, valor_p=pearsonr (x,y)
print(f"coeficiente de correlacion (r):{r:0.4f}")
print (f"{valor_p:0.4f}")
# Out:
# coeficiente de correlacion (r):-0.8801
# 0.0000

# %%
#Interpretación: Hay una relación negativa fuerte. Esto significa que cuando sube la categoría de salario, las ausencias bajan.

# %%
#5 Calcule el coeficiente de determinación e interprete el resultado.
print(f"coeficiente de determinación: {r**2:0.4f}")
# Out:
# coeficiente de determinación: 0.7746

# %%
#6 Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)
modelo.params
# Out:
# const                   47.487603
# categoria_de_salario    -2.958678
# dtype: float64

# %%
# Interpretación: El 77.46% de los cambios en las ausencias se pueden explicar por la categoría salarial. El resto depende de otros factores que no se tomaron en cuenta.

# %%
#7 Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )
modelo.conf_int(alpha=0.05)
# Out:
#                               0          1
# const                 39.707750  55.267457
# categoria_de_salario  -3.962455  -1.954900

# %%
#8 Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos? no hay
#residuales
residuales=modelo.resid
import matplotlib.pyplot as plt
#configuracion general
plt.figure(
    figsize=(6,4), #tamaño (ancho,alto)
    dpi=100 #resoluciom
)
#Grafico de dispersion
plt.scatter(
    x,residuales, #variables a graficar
    marker="H", #cambio de forma de los puntos
    color="#A60790", #YO CAMBIO
    edgecolor="#3D0235", #color del borde
    alpha=0.9, #transparencia
    s=60, #tamaño de cada punto
    label="ausencias" #etiqueta
)
#Titulo
plt.title(
    "Grafica de dispersion",
    fontsize=12, #tamaño de fuente
    fontweight="bold" #bold:negritas
)
#Etiqueta eje x
plt.xlabel(
    "categoria_de_salario",
    fontsize=10
)
#Etiqueta eje y
plt.ylabel(
    "ausencias",
    fontsize=10
)
#Modificar tamaño de fuente (tamaño de Ticks) 10 es un buen tamaño
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Margenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False) #este codigo es para que no quede cuadrado :)

#Malla o cuadricula
plt.grid( #Este hace que se cuadricule la grafica
    visible=True, #True es que si la quieres y cuando se pone False es que no la quieres o no se va a poner (T o F se ponen en mayusculas)
    linestyle="--",
    linewidth=0.7, #ancho de la linea
    alpha=0.5, #transparencia
    color="#AB0392",
    )

#Leyenda (Lo que quiere decir los puntos o estrellas)
plt.legend(
    fontsize=10,
    loc="best",
    frameon=False, #si le ponemos False la cajita va a desaparecer, si le ponemos True va a aparecer
    bbox_to_anchor=(0.5,-0.15)
)
#Guardar imagen (entrar en la carpeta, darle en los 3 puntos y se guarda automaticamente)
plt.savefig(
    "dispersión",
    bbox_inches="tight"
)
plt.axhline(y=0, color="#AB0392", linestyle="--") #linea horizontal

# %%
# Interpretación: En la gráfica de los residuales se ve que los puntos están regados de forma desordenada alrededor del cero y no siguen ningún patrón claro. Esto quiere decir que sí se cumple la linealidad y que la variación es más o menos igual en todos los datos.

# %%
#9 Realice la prueba de Shapiro para los residuales y comente el resultado.
from scipy.stats import shapiro
estadistico, valor_p=shapiro(residuales)
print(f"valor_p:{valor_p:0.4f}")
# Out:
# valor_p:0.8933

# %%
# Interpretación: Como el valor p es mayor que 0.05, se mantiene la hipótesis nula. Esto indica que los residuales se comportan de manera normal y que sí se cumple el supuesto de normalidad en el modelo.

# %%
#10 Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
from statsmodels.stats.api import het_breuschpagan
estadistico_1,valor_p_1,estadistico_2,valor_p_2=het_breuschpagan(residuales,x_constante)
print(f"valor_p:{valor_p_1:0.4f}")
# Out:
# valor_p:0.4505

# %%
# Interpretación: Como el valor p es mayor que 0.05, no se rechaza la hipótesis nula (H0). Esto quiere decir que no hay pruebas de que exista heterocedasticidad, o sea, la variación de los datos es bastante uniforme.

# %%
# 11 Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.

# Interpolar 1:

modelo.predict([1,6])
# Out:
# array([29.73553719])

# %%
# Interpolar 2:
modelo.predict([1,4])
# Out:
# array([35.65289256])

# %%
#Extraexpolar 1:

modelo.predict([1,13])
# Out:
# array([9.02479339])

# %%
# Interpretación: Las interpolaciones son más confiables porque se hacen dentro de los datos que ya se observaron. En cambio, la extrapolación es menos segura porque se hace fuera del rango de información que tenemos.

# %%
#12 Realice una tabla ANOVA e interprete el resultado.
from statsmodels.formula.api import ols
#y ~ x
modelo_lineal=ols ("ausencias ~ categoria_de_salario", data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                         df      sum_sq     mean_sq          F    PR(>F)
# categoria_de_salario   1.0  983.548996  983.548996  41.243954  0.000033
# Residual              12.0  286.165289   23.847107        NaN       NaN

# %%
# Interpretacion: Como el valor-p es menor que 0.05, se rechaza la hipótesis nula. El modelo de regresión es estadísticamente significativo, lo que indica que la categoría salarial explica de manera significativa el número de ausencias.

# %% [markdown]
# ### Problema 3
# A menudo, quienes hacen la contabilidad de costos estiman los gastos generales con base en el nivel de producción. En Standard Knitting Co. han reunido información acerca de los gastos generales y las unidades producidas en diferentes plantas.
#
# | Gastos generales | 191 | 170 | 272 | 155 | 280 | 173 | 234 | 116 | 153 | 178 |
# |------------------|-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|
# | Unidades        |  40 |  42 |  53 |  35 |  56 |  39 |  48 |  30 |  37 |  40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
    "Gastos_generales":[191,170,272,155,280,173,234,116,153,178],
    "unidades":[40,42,53,35,56,39,48,30,37,40]
})
df
# Out:
#    Gastos_generales  unidades
# 0               191        40
# 1               170        42
# 2               272        53
# 3               155        35
# 4               280        56
# 5               173        39
# 6               234        48
# 7               116        30
# 8               153        37
# 9               178        40

# %%
#1 Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
# y una variable independiente (X)
x=df["unidades"]              #variable independiente (con la que cuenta)
y=df["Gastos_generales"]      #variable de interes (variable dependiene)

# %%
#2. Realice un diagrama de dispersión para estos datos.

import pandas as pd
df=pd.DataFrame({
    "Gastos_generales":[191,170,272,155,280,173,234,116,153,178],
    "Unidades_producidas":[40,42,53,35,56,39,48,30,37,40],
})

import matplotlib.pyplot as plt
#configuracion general
plt.figure(
    figsize=(6,4), #tamaño (ancho,alto)
    dpi=100 #resoluciom
)

#Grafico de dispersion
plt.scatter(
    x,y, #variables a graficar
    marker="H",
    color="#F54927",
    edgecolor="#A61D00", #color del borde
    alpha=0.9, #transparencia
    s=60, #tamaño de cada punto
    label="Unidades_producidas" #etiqueta
)

#Titulo
plt.title(
    "Grafica de dispersion",
    fontsize=12, #tamaño de fuente
    fontweight="bold" #bold:negritas
)

#Etiqueta eje x
plt.xlabel(
    "Gastos_generales",
    fontsize=10
)

#Etiqueta eje y
plt.ylabel(
    "Unidades_producidas",
    fontsize=10
)

#Modificar tamaño de fuente (tamaño de Ticks) 10 es un buen tamaño
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Margenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False) #este codigo es para que no quede cuadrado :)

#Malla o cuadricula
plt.grid( #Este hace que se cuadricule la grafica
    visible=True, #True es que si la quieres y cuando se pone False es que no la quieres o no se va a poner (T o F se ponen en mayusculas)
    linestyle="--",
    linewidth=0.7, #ancho de la linea
    alpha=0.5, #transparencia
    color="#38A0BA",
    )

#Leyenda (Lo que quiere decir los puntos o estrellas)
plt.legend(
    fontsize=10,
    loc="best",
    frameon=False, #si le ponemos False la cajita va a desaparecer, si le ponemos True va a aparecer
    bbox_to_anchor=(0.5,-0.15)
)

# %%
# 3 ¿Los datos soportan la suposición de linealidad?
# En la gráfica de dispersión se nota que los puntos van subiendo. Eso significa que cuando aumentan los gastos generales, también aumentan las unidades producidas. Como los puntos casi forman una línea hacia arriba, se puede decir que sí se cumple la suposición de linealidad.

# %%
#4 Calcule el coeficiente de correlación e interprete el resultado.
from scipy.stats import pearsonr
#Test de pearsonr
#H0: rho=0    (no hay correlación)
# H1: rho ≠0  (si hay correlación)
pearsonr (x,y)
print(f"coeficiente de correlacion:{r:0.4f}")
print(f"valor_p:{valor_p:0.4f}")
# Out:
# coeficiente de correlacion:-0.8801
# valor_p:0.8933

# %%
# Interpretación: El coeficiente de correlación (r) muestra qué tan fuerte y en qué dirección es la relación entre las variables. Si el valor p es menor que 0.05, se rechaza la hipótesis nula y se concluye que sí existe una correlación significativa; si es mayor, no hay suficiente evidencia para afirmar que hay relación.

# %%
#5 Calcule el coeficiente de determinación e interprete el resultado.
print(f"coeficiente de determinación:{r**2:0.4f}")
# Out:
# coeficiente de determinación:0.7746

# %%
# Interpretación: El coeficiente de determinación (r²) indica qué porcentaje de los cambios en una variable se pueden explicar por la otra. Mientras más alto sea su valor, mejor es el ajuste del modelo y mayor es la parte que se logra explicar.

# %%
#6 Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)
modelo.params
# Out:
# const      -80.442857
# unidades     6.491497
# dtype: float64

# %%
import matplotlib.pyplot as plt
#configuracion general
plt.figure(
    figsize=(6,4), #tamaño (ancho,alto)
    dpi=100 #resoluciom
)
plt.scatter(
    x,y, #variables a graficar
    marker=".", #cambio de forma de los puntos
    color="#e330b2",
    edgecolor="#ab1281", #color del borde
    alpha=0.9, #transparencia
    s=60, #tamaño de cada punto
    label="unidades" #etiqueta
)
plt.plot(
    x,y_calculada,
)
#Titulo
plt.title(
    "Grafica de dispersion",
    fontsize=12, #tamaño de fuente
    fontweight="bold" #bold:negritas
)

#Etiqueta eje x
plt.xlabel(
    "Gastos_generales",
    fontsize=10
)
#Etiqueta eje y
plt.ylabel(
    "unidades",
    fontsize=10
)

#Modificar tamaño de fuente (tamaño de Ticks) 10 es un buen tamaño
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Margenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False) #este codigo es para que no quede cuadrado :)

#Malla o cuadricula
plt.grid( #Este hace que se cuadricule la grafica
    visible=True, #True es que si la quieres y cuando se pone False es que no la quieres o no se va a poner (T o F se ponen en mayusculas)
    linestyle="--",
    linewidth=0.7, #ancho de la linea
    alpha=0.5, #transparencia
    color="#000000",
    )

#Leyenda (Lo que quiere decir los puntos o estrellas)
plt.legend(
    fontsize=10,
    loc="best",
    frameon=False, #si le ponemos False la cajita va a desaparecer, si le ponemos True va a aparecer
    bbox_to_anchor=(0.5,-0.15)
)

#Guardar imagen (entrar en la carpeta, darle en los 3 puntos y se guarda automaticamente)
plt.savefig(
    "dispersión",
    bbox_inches="tight"
)

# %%
#7 Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )
modelo.conf_int(alpha=0.05)
# Out:
#                    0          1
# const    -121.986373 -38.899341
# unidades    5.518450   7.464543

# %%
#8 Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos? no hay
#residuales
residuales=modelo.resid
import matplotlib.pyplot as plt
#configuracion general
plt.figure(
    figsize=(6,4), #tamaño (ancho,alto)
    dpi=100 #resoluciom
)
#Grafico de dispersion
plt.scatter(
    x,residuales, #variables a graficar
    marker="H", #cambio de forma de los puntos
    color="#A60790", #YO CAMBIO
    edgecolor="#3D0235", #color del borde
    alpha=0.9, #transparencia
    s=60, #tamaño de cada punto
    label="unidades" #etiqueta
)
#Titulo
plt.title(
    "Grafica de dispersion",
    fontsize=12, #tamaño de fuente
    fontweight="bold" #bold:negritas
)
#Etiqueta eje x
plt.xlabel(
    "Gastos_generales",
    fontsize=10
)
#Etiqueta eje y
plt.ylabel(
    "unidades",
    fontsize=10
)
#Modificar tamaño de fuente (tamaño de Ticks) 10 es un buen tamaño
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Margenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False) #este codigo es para que no quede cuadrado :)

#Malla o cuadricula
plt.grid( #Este hace que se cuadricule la grafica
    visible=True, #True es que si la quieres y cuando se pone False es que no la quieres o no se va a poner (T o F se ponen en mayusculas)
    linestyle="--",
    linewidth=0.7, #ancho de la linea
    alpha=0.5, #transparencia
    color="#AB0392",
    )

#Leyenda (Lo que quiere decir los puntos o estrellas)
plt.legend(
    fontsize=10,
    loc="best",
    frameon=False, #si le ponemos False la cajita va a desaparecer, si le ponemos True va a aparecer
    bbox_to_anchor=(0.5,-0.15)
)
#Guardar imagen (entrar en la carpeta, darle en los 3 puntos y se guarda automaticamente)
plt.savefig(
    "dispersión",
    bbox_inches="tight"
)
plt.axhline(y=0, color="#AB0392", linestyle="--") #linea horizontal

# %%
# Interpretación: Al graficar los residuales, se observa que los puntos están distribuidos de manera dispersa alrededor de la línea cero y no siguen ningún patrón específico. Esto indica que sí se cumplen los supuestos del modelo, ya que hay linealidad y la variación es constante (no se ve heterocedasticidad).

# %%
#9 Realice la prueba de Shapiro para los residuales y comente el resultado.
from scipy.stats import shapiro
estadistico, valor_p=shapiro(residuales)
print(f"valor_p:{valor_p:0.4f}")
# Out:
# valor_p:0.2205

# %%
# Interpretación: Con la prueba de Shapiro se revisa si los residuales siguen una distribución normal. Si el valor p es mayor que 0.05, no se rechaza la hipótesis nula y se concluye que sí cumplen con la normalidad. Si es menor que 0.05, entonces no siguen una distribución normal.

# %%
#10 Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
from statsmodels.stats.api import het_breuschpagan
estadistico_1,valor_p_1,estadistico_2,valor_p_2=het_breuschpagan(residuales,x_constante)
print(f"valor_p:{valor_p_1:0.4f}")
# Out:
# valor_p:0.9858

# %%
# Interpretación: Con la prueba de Breusch-Pagan se revisa si existe heterocedasticidad (cambios en la variación de los errores). Si el valor p es mayor que 0.05, no se rechaza la hipótesis nula y se concluye que no hay heterocedasticidad. Si el valor p es menor que 0.05, significa que sí hay evidencia de heterocedasticidad.

# %%
#11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.

# Interpolar 1:

modelo.predict([1,45])
# Out:
# array([211.6744898])

# %%
#Interpolar 2:

modelo.predict([1,50])
# Out:
# array([244.13197279])

# %%
#Extrapolar:

modelo.predict([1,65])
# Out:
# array([341.50442177])

# %%
# Interpretación: Las dos primeras predicciones (45 y 50) son interpolaciones porque están dentro del rango de los datos observados, por lo que son más confiables. La predicción con 65 es una extrapolación, ya que está fuera del rango de los datos originales, así que puede ser menos precisa y debe tomarse con más cuidado.

# %%
#12. Test de ANOVA
from statsmodels.formula.api import ols
# y~x
modelo_lineal=ols("Unidades_producidas~Gastos_generales",data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                    df      sum_sq     mean_sq           F        PR(>F)
# Gastos_generales  1.0  568.774067  568.774067  236.669535  3.167080e-07
# Residual          8.0   19.225933    2.403242         NaN           NaN

# %%
# Interpretación: En la tabla ANOVA se observa que el valor p (3.16708e-07) es mucho menor que 0.05, por lo tanto se rechaza la hipótesis nula. Esto significa que el modelo de regresión es estadísticamente significativo y que los gastos generales sí influyen de manera importante en las unidades producidas.

# %% [markdown]
# ### Problema 4
# Las ventas de línea blanca varían según el estado del mercado de casas nuevas: cuando las ventas de casas nuevas son buenas, también lo son las de lavaplatos, lavadoras de ropa, secadoras y refrigeradores.
# Una asociación de comercio compiló los siguientes datos históricos (en miles de unidades) de las ventas de línea blanca y la construcción de casas.
#
# | Construcción de casas (miles) | Ventas de línea blanca (miles) |
# |-------------------------------|--------------------------------|
# | 2.0                           | 5.0                            |
# | 2.5                           | 5.5                            |
# | 3.2                           | 6.0                            |
# | 3.6                           | 7.0                            |
# | 3.7                           | 7.2                            |
# | 4.0                           | 7.7                            |
# | 4.2                           | 8.4                            |
# | 4.6                           | 9.0                            |
# | 4.8                           | 9.7                            |
# | 5.0                           | 10.0                           |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
# 1 Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
import pandas as pd
df=pd.DataFrame({
    "costruccion_de_casas":[2.0,2.5,3.2,3.6,3.7,4.0,4.2,4.6,4.8,5.0],
    "ventas_de_lineas_blancas":[5.0,5.5,6.0,7.0,7.2,7.7,8.4,9.0,9.7,10.0]
})
df
# Out:
#    costruccion_de_casas  ventas_de_lineas_blancas
# 0                   2.0                       5.0
# 1                   2.5                       5.5
# 2                   3.2                       6.0
# 3                   3.6                       7.0
# 4                   3.7                       7.2
# 5                   4.0                       7.7
# 6                   4.2                       8.4
# 7                   4.6                       9.0
# 8                   4.8                       9.7
# 9                   5.0                      10.0

# %%
# 2 Realice un diagrama de dispersión para estos datos.
import pandas as pd
df=pd.DataFrame({
    "costruccion_de_casas":[2.0,2.5,3.2,3.6,3.7,4.0,4.2,4.6,4.8,5.0],
    "ventas_de_lineas_blancas":[5.0,5.5,6.0,7.0,7.2,7.7,8.4,9.0,9.7,10.0]
})
import matplotlib.pyplot as plt
#configuracion general
plt.figure(
    figsize=(6,4), #tamaño (ancho,alto)
    dpi=100 #resoluciom
)
#Definir variables
x=df["costruccion_de_casas"]
y=df["ventas_de_lineas_blancas"]
#Grafico de dispersion
plt.scatter(
    x,y, #variables a graficar
    marker=".", #cambio de forma de los puntos
    color="#e330b2",
    edgecolor="#ab1281", #color del borde
    alpha=0.9, #transparencia
    s=60, #tamaño de cada punto
    label="ventas_de_lineas_blancas" #etiqueta
)
#Titulo
plt.title(
    "Grafica de dispersion",
    fontsize=12, #tamaño de fuente
    fontweight="bold" #bold:negritas
)
#Etiqueta eje x
plt.xlabel(
    "costruccion_de_casas",
    fontsize=10
)
#Etiqueta eje y
plt.ylabel(
    "ventas_de_lineas_blancas",
    fontsize=10
)

#Modificar tamaño de fuente (tamaño de Ticks) 10 es un buen tamaño
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Margenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False) #este codigo es para que no quede cuadrado :)

#Malla o cuadricula
plt.grid( #Este hace que se cuadricule la grafica
    visible=True, #True es que si la quieres y cuando se pone False es que no la quieres o no se va a poner (T o F se ponen en mayusculas)
    linestyle="--",
    linewidth=0.7, #ancho de la linea
    alpha=0.5, #transparencia
    color="#000000",
    )
#Leyenda (Lo que quiere decir los puntos o estrellas)
plt.legend(
    fontsize=10,
    loc="best",
    frameon=False, #si le ponemos False la cajita va a desaparecer, si le ponemos True va a aparecer
    bbox_to_anchor=(0.5,-0.15)
)

#Guardar imagen (entrar en la carpeta, darle en los 3 puntos y se guarda automaticamente)
plt.savefig(
    "dispersión",
    bbox_inches="tight"
)

# %%
# 3 ¿Los datos soportan la suposición de linealidad?
# En la gráfica de dispersión se observa que los puntos van hacia arriba. Esto quiere decir que cuando aumenta la construcción de casas, también suben las ventas de línea blanca. Como los datos casi forman una línea recta ascendente, se puede decir que sí se cumple la suposición de linealidad.

# %%
# 4 Calcule el coeficiente de correlación e interprete el resultado.
#r=1 obtenemos una relación muy fuerte (perfecta hacia arriba)
#r=-1 obtenemos una relación muy fuerte pero al contrario (va hacia abajo)
#r=0 no hay correlación (obtenemos una relación nula)
from scipy.stats import pearsonr
r, valor_p=pearsonr (x,y)             #prueba de hipotesis
print(f"coeficiente de correlacion (r):{r:0.4f}")                                      #Ho:p=o no hay correción
print (f"{valor_p:0.4f}")                                                               #Hi:p=/o si hay correción
                                                                                       #corralación:el cambio de una variable esta vinculado con el cambio en otra variable
# Out:
# coeficiente de correlacion (r):0.9808
# 0.0000

# %%
# Interpretación: Como el valor p es menor que 0.05, se rechaza la hipótesis nula. Esto significa que sí hay suficiente evidencia para decir que existe una relación lineal importante entre las dos variables. Además, el valor de r muestra que la relación es positiva y muy fuerte.

# %%
# 5
print(f"coeficiente de determinación: {r**2:0.4f}")
# Out:
# coeficiente de determinación: 0.9619

# %%
# Interpretación: Esto quiere decir que el 96.19% de los cambios en las ventas de línea blanca se pueden explicar por la construcción de casas. El 3.81% restante se debe a otras cosas que no se tomaron en cuenta en el modelo.

# %%
# 6
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)
modelo.params
# Out:
# const                   1.016760
# costruccion_de_casas    1.737564
# dtype: float64

# %%
#7 Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )
modelo.conf_int(alpha=0.05)
# Out:
#                              0         1
# const                -0.074848  2.108368
# costruccion_de_casas  1.455693  2.019435

# %%
#8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?

residuales=modelo.resid
import matplotlib.pyplot as plt
#configuracion general
plt.figure(
    figsize=(6,4), #tamaño (ancho,alto)
    dpi=100 #resoluciom
)

#Grafico de dispersion
plt.scatter(
    x,residuales, #variables a graficar
    marker=".", #cambio de forma de los puntos
    color="#e330b2",
    edgecolor="#ab1281", #color del borde
    alpha=0.9, #transparencia
    s=60, #tamaño de cada punto
    label="ventas_de_linea_blanca" #etiqueta
)

#Titulo
plt.title(
    "Grafica de dispersion",
    fontsize=12, #tamaño de fuente
    fontweight="bold" #bold:negritas
)

#Etiqueta eje x
plt.xlabel(
    "construccion_de_casas",
    fontsize=10
)

#Etiqueta eje y
plt.ylabel(
    "ventas_de_linea_blanca",
    fontsize=10
)

#Modificar tamaño de fuente (tamaño de Ticks) 10 es un buen tamaño
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Margenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False) #este codigo es para que no quede cuadrado :)

#Malla o cuadricula
plt.grid( #Este hace que se cuadricule la grafica
    visible=True, #True es que si la quieres y cuando se pone False es que no la quieres o no se va a poner (T o F se ponen en mayusculas)
    linestyle="--",
    linewidth=0.7, #ancho de la linea
    alpha=0.5, #transparencia
    color="#B6DE99",
    )

#Leyenda (Lo que quiere decir los puntos o estrellas)
plt.legend(
    fontsize=10,
    loc="best",
    frameon=False, #si le ponemos False la cajita va a desaparecer, si le ponemos True va a aparecer
    bbox_to_anchor=(0.5,-0.15)
)

plt.axhline(y=0, color="#8F0744", linestyle="--") #linea horizontal

# %%
# Interpretación: En la gráfica de los residuales se ve que los puntos están dispersos alrededor del cero y no forman ningún patrón claro. Esto quiere decir que sí se cumplen los supuestos de linealidad y que la variación es constante en el modelo.

# %%
#9 Realice la prueba de Shapiro para los residuales y comente el resultado.
from scipy.stats import shapiro
estadistico, valor_p=shapiro(residuales)
print(f"valor_p:{valor_p:0.4f}")
# Out:
# valor_p:0.8464

# %%
# Interpretación: Como el valor p es mayor que 0.05, no se rechaza la hipótesis nula. Esto significa que los residuales sí se comportan de forma normal y que se cumple el supuesto de normalidad.

# %%
#10 Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
from statsmodels.stats.api import het_breuschpagan
estadistico_1,valor_p_1,estadistico_2,valor_p_2=het_breuschpagan(residuales,x_constante)
print(f"valor_p:{valor_p_1:0.4f}")
# Out:
# valor_p:0.1581

# %%
# Interpretación: Como el valor p es mayor que 0.05, no se rechaza la hipótesis nula. Esto quiere decir que no hay pruebas de heterocedasticidad y que la varianza se mantiene constante en el modelo.

# %%
#11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.

# Interpolar 1:

modelo.predict([1,3.5])
# Out:
# array([7.09823338])

# %%
#interpolar 2:

modelo.predict([1,4.4])
# Out:
# array([8.66204091])

# %%
#Extraexpolar

modelo.predict([1,6.0])
# Out:
# array([11.44214319])

# %%
#Interpretación: Cuando el valor es 3.5 se estiman 7.10 ventas y para 4.4 se estiman 8.66 ventas. Estos resultados son interpolaciones porque están dentro del rango de los datos que ya se tenían, por eso son más confiables.
# En cambio, para 6.0 se estiman 11.44 ventas, pero este es un caso de extrapolación, ya que está fuera del rango observado, así que se debe tomar con más cuidado.

# %% [markdown]
# ### Problema 5
# William C. Andrews, consultor de comportamiento organizacional de Victory Motorcycles, ha diseñado una prueba para mostrar a los supervisores de la compañía los peligros de sobrevigilar a sus trabajadores.
# Un trabajador de la línea de ensamble tiene a su cargo una serie de tareas complicadas. Durante el desempeño del trabajador, un inspector lo interrumpe constantemente para ayudarlo a terminar las tareas.
# El trabajador, después de terminar su trabajo, recibe una prueba psicológica diseñada para medir la hostilidad del trabajador hacia la autoridad
# (una alta puntuación implica una hostilidad baja). A ocho distintos trabajadores se les asignaron las tareas y luego se les interrumpió para darles instrucciones útiles un número variable de veces (línea X).
# Sus calificaciones en la prueba de hostilidad se dan en el renglón Y.
#
# | número interrupciones al trabajador |  5  | 10  | 10  | 15  | 15  | 20  | 20  | 25  |
# |-----------------------------------------|----|----|----|----|----|----|----|----|
# | calificación del trabajador en la prueba de hostilidad | 58  | 41  | 45  | 27  | 26  | 12  | 16  |  3  |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
    "numero_interrupciones_al_trabajador":[5,10,10,15,15,20,20,25],
    "calificacion_trabajador_en_la_prueba_de_hostilidad":[58,41,45,27,26,12,16,3]
})
df
# Out:
#    numero_interrupciones_al_trabajador  \
# 0                                    5
# 1                                   10
# 2                                   10
# 3                                   15
# 4                                   15
# 5                                   20
# 6                                   20
# 7                                   25
#
#    calificacion_trabajador_en_la_prueba_de_hostilidad
# 0                                                 58
# 1                                                 41
# 2                                                 45
# 3                                                 27
# 4                                                 26
# 5                                                 12
# 6                                                 16
# 7                                                  3

# %%
#2 Realice un diagrama de dispersión para estos datos
import matplotlib.pyplot as plt
#configuracion general
plt.figure(
    figsize=(6,4), #tamaño (ancho,alto)
    dpi=100 #resoluciom
)
#Definir variables
x=df["numero_interrupciones_al_trabajador"]
y=df["calificacion_trabajador_en_la_prueba_de_hostilidad"]
#Grafico de dispersion
plt.scatter(
    x,y, #variables a graficar
    marker=".", #cambio de forma de los puntos
    color="#e330b2",
    edgecolor="#ab1281", #color del borde
    alpha=0.9, #transparencia
    s=60, #tamaño de cada punto
    label="calificacion_trabajador_en_la_prueba_de_hostilidad" #etiqueta
)
#Titulo
plt.title(
    "Grafica de dispersion",
    fontsize=12, #tamaño de fuente
    fontweight="bold" #bold:negritas
)

#Etiqueta eje x
plt.xlabel(
    "numero_interrupciones_al_trabajador",
    fontsize=10
)
#Etiqueta eje y
plt.ylabel(
    "calificacion_trabajador_en_la_prueba_de_hostilidad",
    fontsize=10
)

#Modificar tamaño de fuente (tamaño de Ticks) 10 es un buen tamaño
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Margenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False) #este codigo es para que no quede cuadrado :)

#Malla o cuadricula
plt.grid( #Este hace que se cuadricule la grafica
    visible=True, #True es que si la quieres y cuando se pone False es que no la quieres o no se va a poner (T o F se ponen en mayusculas)
    linestyle="--",
    linewidth=0.7, #ancho de la linea
    alpha=0.5, #transparencia
    color="#000000",
    )

#Leyenda (Lo que quiere decir los puntos o estrellas)
plt.legend(
    fontsize=10,
    loc="best",
    frameon=False, #si le ponemos False la cajita va a desaparecer, si le ponemos True va a aparecer
    bbox_to_anchor=(0.5,-0.15)
)

#Guardar imagen (entrar en la carpeta, darle en los 3 puntos y se guarda automaticamente)
plt.savefig(
    "dispersión",
    bbox_inches="tight"
)

# %%
#3 ¿Los datos soportan la suposición de linealidad?
#Respuesta: En la gráfica se observa que los puntos van hacia abajo. Esto significa que mientras más interrupciones hay, menor es la calificación. Como los datos casi forman una línea descendente, se puede decir que sí se cumple la suposición de linealidad.

# %%
#4 Calcule el coeficiente de correlación e interprete el resultado.
from scipy.stats import pearsonr
r, valor_p=pearsonr (x,y)             #prueba de hipotesis
print(f"coeficiente de correlacion (r):{r:0.4f}")
print (f"{valor_p:0.4f}")
# Out:
# coeficiente de correlacion (r):-0.9928
# 0.0000

# %%
# Interpretación: Como el valor-p es menor que 0.05, se rechaza la hipótesis nula. Existe evidencia estadística suficiente para afirmar que hay una relación lineal significativa entre ambas variables. El valor de r indica que la relación es negativa y extremadamente fuerte.

# %%
# 5Calcule el coeficiente de determinación e interprete el resultado.
print(f"coeficiente de determinación: {r**2:0.4f}")
# Out:
# coeficiente de determinación: 0.9858

# %%
# Interpretación: Esto quiere decir que el 98.58% de los cambios en la calificación se pueden explicar por el número de interrupciones. Por eso se puede decir que el modelo tiene un ajuste casi perfecto.

# %%
#6 Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)
modelo.params
# Out:
# const                                  70.5
# numero_interrupciones_al_trabajador    -2.8
# dtype: float64

# %%
import pandas as pd
df=pd.DataFrame({
    "promedio_de_examenes_cortos":[59,92,72,90,95,87,89,77,76,65,97,42,94,62,91],
    "promedio_final":[64,84,77,80,77,81,80,84,80,69,83,40,78,65,90]
})
import matplotlib.pyplot as plt
#configuracion general
plt.figure(
    figsize=(6,4), #tamaño (ancho,alto)
    dpi=100 #resoluciom
)
plt.scatter(
    x,y, #variables a graficar
    marker=".", #cambio de forma de los puntos
    color="#e330b2",
    edgecolor="#ab1281", #color del borde
    alpha=0.9, #transparencia
    s=60, #tamaño de cada punto
    label="calificacion_trabajador_en_la_prueba_de_hostilidad" #etiqueta
)
plt.plot(
    x,y_calculada,
)
#Titulo
plt.title(
    "Grafica de dispersion",
    fontsize=12, #tamaño de fuente
    fontweight="bold" #bold:negritas
)

#Etiqueta eje x
plt.xlabel(
    "numero_interrupciones_al_trabajador",
    fontsize=10
)
#Etiqueta eje y
plt.ylabel(
    "calificacion_trabajador_en_la_prueba_de_hostilidad",
    fontsize=10
)

#Modificar tamaño de fuente (tamaño de Ticks) 10 es un buen tamaño
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Margenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False) #este codigo es para que no quede cuadrado :)

#Malla o cuadricula
plt.grid( #Este hace que se cuadricule la grafica
    visible=True, #True es que si la quieres y cuando se pone False es que no la quieres o no se va a poner (T o F se ponen en mayusculas)
    linestyle="--",
    linewidth=0.7, #ancho de la linea
    alpha=0.5, #transparencia
    color="#000000",
    )

#Leyenda (Lo que quiere decir los puntos o estrellas)
plt.legend(
    fontsize=10,
    loc="best",
    frameon=False, #si le ponemos False la cajita va a desaparecer, si le ponemos True va a aparecer
    bbox_to_anchor=(0.5,-0.15)
)

#Guardar imagen (entrar en la carpeta, darle en los 3 puntos y se guarda automaticamente)
plt.savefig(
    "dispersión",
    bbox_inches="tight"
)

# %%
#7 Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )
modelo.conf_int(alpha=0.05)
# Out:
#                                              0          1
# const                                65.051384  75.948616
# numero_interrupciones_al_trabajador  -3.136296  -2.463704

# %%
#8 Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos? no hay
#residuales
residuales=modelo.resid
import matplotlib.pyplot as plt
#configuracion general
plt.figure(
    figsize=(6,4), #tamaño (ancho,alto)
    dpi=100 #resoluciom
)
#Grafico de dispersion
plt.scatter(
    x,residuales, #variables a graficar
    marker="H", #cambio de forma de los puntos
    color="#A60790", #YO CAMBIO
    edgecolor="#3D0235", #color del borde
    alpha=0.9, #transparencia
    s=60, #tamaño de cada punto
    label="calificacion_trabajador_en_la_prueba_de_hostilidad" #etiqueta
)
#Titulo
plt.title(
    "Grafica de dispersion",
    fontsize=12, #tamaño de fuente
    fontweight="bold" #bold:negritas
)
#Etiqueta eje x
plt.xlabel(
    "numero_interrupciones_al_trabajador",
    fontsize=10
)
#Etiqueta eje y
plt.ylabel(
    "calificacion_trabajador_en_la_prueba_de_hostilidad",
    fontsize=10
)
#Modificar tamaño de fuente (tamaño de Ticks) 10 es un buen tamaño
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

#Margenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False) #este codigo es para que no quede cuadrado :)

#Malla o cuadricula
plt.grid( #Este hace que se cuadricule la grafica
    visible=True, #True es que si la quieres y cuando se pone False es que no la quieres o no se va a poner (T o F se ponen en mayusculas)
    linestyle="--",
    linewidth=0.7, #ancho de la linea
    alpha=0.5, #transparencia
    color="#AB0392",
    )

#Leyenda (Lo que quiere decir los puntos o estrellas)
plt.legend(
    fontsize=10,
    loc="best",
    frameon=False, #si le ponemos False la cajita va a desaparecer, si le ponemos True va a aparecer
    bbox_to_anchor=(0.5,-0.15)
)
#Guardar imagen (entrar en la carpeta, darle en los 3 puntos y se guarda automaticamente)
plt.savefig(
    "dispersión",
    bbox_inches="tight"
)
plt.axhline(y=0, color="#AB0392", linestyle="--") #linea horizontal

# %%
# Respuesta: Los residuales están dispersos alrededor del cero y no siguen ningún patrón claro. Esto muestra que sí se cumplen las condiciones del modelo.

# %%
#9 Realice la prueba de Shapiro para los residuales y comente el resultado.
from scipy.stats import shapiro
estadistico, valor_p=shapiro(residuales)
print(f"valor_p:{valor_p:0.4f}")
# Out:
# valor_p:0.0548

# %%
# Interpretación: Como el valor p es un poco mayor que 0.05, no se rechaza la hipótesis nula. Esto quiere decir que se puede considerar que hay normalidad, aunque el resultado está muy cerca del nivel de significancia y debe interpretarse con cuidado.

# %%
#10 Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
from statsmodels.stats.api import het_breuschpagan
estadistico_1,valor_p_1,estadistico_2,valor_p_2=het_breuschpagan(residuales,x_constante)
print(f"valor_p:{valor_p_1:0.4f}")
# Out:
# valor_p:0.2482

# %%
# Interpretación: Como el valor p es mayor que 0.05, no se rechaza la hipótesis nula. Esto significa que no se encontraron pruebas de heterocedasticidad y que la variación de los datos se mantiene constante.

# %%
#11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.

# Interpolar 1:

modelo.predict([1,12])
# Out:
# array([36.9])

# %%
# Interpolar 2:

modelo.predict([1,18])
# Out:
# array([20.1])

# %%
#Extrapolar:

modelo.predict([1,30])
# Out:
# array([-13.5])

# %%
# Interpretación: Cuando hay 12 interrupciones se estiman 36.9 puntos y con 18 interrupciones se estiman 20.1 puntos. Estos resultados son interpolaciones porque están dentro del rango de los datos observados, por eso se consideran confiables.
#En cambio, con 30 interrupciones se estiman −13.5 puntos. Este es un caso de extrapolación, ya que está fuera del rango de los datos y además el resultado no es realista, así que el modelo no debe usarse fuera del rango observado.

# %%
#12 Realice una tabla ANOVA e interprete el resultado.
from statsmodels.formula.api import ols
import statsmodels.api as sm
import pandas as pd

# Redefine the DataFrame for Problem 5 to ensure correct data is used
df = pd.DataFrame({
    "numero_interrupciones_al_trabajador":[5,10,10,15,15,20,20,25],
    "calificacion_trabajador_en_la_prueba_de_hostilidad":[58,41,45,27,26,12,16,3]
})

# Crear un DataFrame temporal con nombres de columna más cortos para el modelo OLS
df_temp = df.rename(columns={
    "calificacion_trabajador_en_la_prueba_de_hostilidad": "hostilidad",
    "numero_interrupciones_al_trabajador": "interrupciones"
})

# Ajustar el modelo lineal con los nombres de columna simplificados
modelo_lineal = ols(
    "hostilidad ~ interrupciones",
    data=df_temp
).fit()

# Realizar la tabla ANOVA
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                  df  sum_sq      mean_sq           F        PR(>F)
# interrupciones  1.0  2352.0  2352.000000  415.058824  9.090964e-07
# Residual        6.0    34.0     5.666667         NaN           NaN

# %%
# Interpretación: Como el valor p es menor que 0.05, se rechaza la hipótesis nula. Esto significa que el modelo de regresión sí es significativo y que el número de interrupciones influye de forma importante en la calificación de hostilidad.
